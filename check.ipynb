# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

df = pd.read_csv('data6 (copy).csv')

df = df.loc[:, :'yaw']
print(df.to_string())
df.to_csv('data6.csv', index=False)


# print(df['yaw'].to_string())
# Out:
#         time      ax       ay       az       yaw
# 0      0.000  0.0166  0.03685   9.8658    0.0000
# 1      0.043  0.0237 -0.27918   9.8143  340.3018
# 2      0.086  0.0106 -0.11066   9.9268  322.0084
# 3      0.129 -0.1103 -0.08030   9.8741  306.9310
# 4      0.172 -0.1115  0.00924   9.9292  295.6838
# 5      0.215 -0.0601  0.12903   9.6766  287.8154
# 6      0.258 -0.0038  0.05005   9.8011  282.4937
# 7      0.301 -0.0098  0.17248   9.7820  278.9474
# 8      0.344  0.0477 -0.15543   9.7904  276.5872
# 9      0.387 -0.0158  0.10142   9.7987  275.0317
# 10     0.430  0.0261 -0.08558   9.9819  274.0186
# 11     0.473 -0.0289 -0.03949   9.8706  273.3562
# 12     0.516 -0.0074  0.02629  10.0681  272.9212
# 13     0.559 -0.0577 -0.03817  10.0944  272.6422
# 14     0.602 -0.0230  0.33319   9.8538  272.4671
# 15     0.645  0.1722  0.07238   9.9951  272.3515
# 16     0.688  0.0142  0.33319  10.3290  272.2517
# 17     0.731  0.0453  0.20284  10.1064  272.1879
# ...
